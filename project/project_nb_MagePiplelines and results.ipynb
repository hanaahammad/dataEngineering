# %% [markdown]
# # 1 Preparing the environment

# %% [markdown]
# Setting up a Mage docker image as per the link:
# https://github.com/mage-ai/mage-zoomcamp

# %% [markdown]
# ## The first mage pipeline
#
# reading a file
# createa partitions on GC bucket
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Link on GitHub

# %% [markdown]
# https://github.com/hanaahammad/dataEngineering/tree/main/project/first_Mage_pipeline/mage_example

# %% [markdown]
# ## Second pipeline
# first docker image crashed
# the second one has only 3 blocks
#
# - load a parquet file from the bucket (yellow_tripdata_2024-01.parquet)
# - change collumns names to a uniform format
# - export to Big Query
#
# result is shown below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### pipeling on Mage image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ####  Loader : Load the dataset from the GC storage bucket

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Transformer: just change the columns names

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### SQL Export  to BQ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Link on GitHub

# %% [markdown]
# https://github.com/hanaahammad/dataEngineering/tree/main/project/first_Mage_pipeline/mage_example/magic-zoomcamp

# %% [markdown]
# ## Preparing GCP

# %% [markdown]
# ### creating a new project

# %% [markdown]
# de-mage

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### creating a bucket on GC storage

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Creating a Compute engine on GCP and installing Docker

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://jedri.medium.com/run-docker-compose-on-gce-a5a49f64225e
#
# https://medium.com/cloudnloud/getting-started-with-google-cloud-compute-engine-and-docker-3370857b04b0

# %% [markdown]
# ### References
#
# #### https://medium.com/@kangzhiyong1999/using-mage-as-the-workflow-orchestration-tools-ef7547fb18fc
# #### https://medium.com/@ofelipefernandez/mage-etl-to-google-cloud-and-bigquery-72d79e9b5f33

# %% [markdown]
# ### Code on GitHub

# %% [markdown]
# # Accessing BQ from NB on Colab

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://console.cloud.google.com/bigquery?ws=!1m7!1m6!12m5!1m3!1sde-mage!2sus-east1!3s17993544-1e29-4eac-b001-9cd468b98428!2e2
